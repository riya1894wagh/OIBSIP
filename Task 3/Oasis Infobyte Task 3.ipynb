# %% [markdown]
# # Oasis Infobyte

# %% [markdown]
# ## Task 3 : Car Price Prediction

# %% [markdown]
#  The price of a car depends on a lot of factors like the goodwill of the **brand of the car** , **features of the car** , **horsepower** and **the mileage** it gives and many more. Car priceprediction is one of the major research areas in machine learning. So if you want to learn how to train a car price prediction model then this project is for you.

# %% [markdown]
# ## 1. Import all necessary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Import dataframe

# %%
df = pd.read_csv("car.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ## 3. Check for Null Values

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# **we don't have null values**

# %% [markdown]
# ## 4. Check for Dublicate row

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **we don't have dublicate row**

# %% [markdown]
# ## 5. Summery of data

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# ## 6. Check column name

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# ## 7. Check the datatype

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %% [markdown]
# ## 8.Shape of dataset

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# ## 9. Find Corelation of data

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# ## 10. Analysing the 'price' column

# %%
df["price"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
df["price"].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.plot(df["price"])

# %%
sns.histplot(df["price"])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.boxplot(df["price"])
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# ## 11. Analysing the Independent  column

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df["symboling"].unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
df["symboling"].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.histplot(x = "symboling" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %%
df["fueltype"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df["fueltype"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
sns.histplot(x = "fueltype" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='price'>

# %%
df["aspiration"].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
sns.histplot(x="aspiration" , y="price" , data = df )
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='price'>

# %%
df["doornumber"].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df["doornumber"].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
sns.histplot(x="doornumber" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='doornumber', ylabel='price'>

# %%
df["carbody"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df["carbody"].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
sns.histplot(x = "carbody" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %%
df["drivewheel"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df["drivewheel"].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.histplot(x = "drivewheel" , y = "price" , data = df )
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='price'>

# %%
df["enginetype"].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df["enginetype"].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
sns.histplot(x="enginetype" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='enginetype', ylabel='price'>

# %%
df["cylindernumber"].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df["cylindernumber"].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
sns.histplot(x="cylindernumber" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='cylindernumber', ylabel='price'>

# %%
df["enginesize"].unique()
# Out:
# array([130, 152, 109, 136, 131, 108, 164, 209,  61,  90,  98, 122, 156,
#         92,  79, 110, 111, 119, 258, 326,  91,  70,  80, 140, 134, 183,
#        234, 308, 304,  97, 103, 120, 181, 151, 194, 203, 132, 121, 146,
#        171, 161, 141, 173, 145], dtype=int64)

# %%
df["enginesize"].value_counts()
# Out:
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 181     6
# 146     6
# 121     6
# 156     5
# 136     5
# 91      5
# 183     4
# 130     4
# 171     3
# 70      3
# 194     3
# 209     3
# 164     3
# 258     2
# 140     2
# 134     2
# 234     2
# 132     2
# 131     2
# 173     1
# 203     1
# 161     1
# 80      1
# 151     1
# 103     1
# 304     1
# 308     1
# 326     1
# 119     1
# 111     1
# 79      1
# 61      1
# 145     1
# Name: enginesize, dtype: int64

# %%
 sns.histplot(x="enginesize" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='price'>

# %%
df["boreratio"].unique()
# Out:
# array([3.47, 2.68, 3.19, 3.13, 3.5 , 3.31, 3.62, 2.91, 3.03, 2.97, 3.34,
#        3.6 , 2.92, 3.15, 3.43, 3.63, 3.54, 3.08, 3.33, 3.39, 3.76, 3.58,
#        3.46, 3.8 , 3.78, 3.17, 3.35, 3.59, 2.99, 3.7 , 3.61, 3.94, 3.74,
#        2.54, 3.05, 3.27, 3.24, 3.01])

# %%
df["boreratio"].value_counts()
# Out:
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.58     6
# 3.39     6
# 3.33     6
# 3.05     6
# 3.54     6
# 3.70     5
# 3.01     5
# 3.35     4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.47     2
# 3.94     2
# 3.24     2
# 3.63     2
# 3.13     2
# 3.80     2
# 3.50     2
# 2.54     1
# 3.08     1
# 3.61     1
# 3.34     1
# 2.68     1
# 3.60     1
# 2.92     1
# 3.76     1
# 2.99     1
# Name: boreratio, dtype: int64

# %%
 sns.histplot(x="boreratio" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='price'>

# %%
  df["stroke"].unique()
# Out:
# array([2.68 , 3.47 , 3.4  , 2.8  , 3.19 , 3.39 , 3.03 , 3.11 , 3.23 ,
#        3.46 , 3.9  , 3.41 , 3.07 , 3.58 , 4.17 , 2.76 , 3.15 , 3.255,
#        3.16 , 3.64 , 3.1  , 3.35 , 3.12 , 3.86 , 3.29 , 3.27 , 3.52 ,
#        2.19 , 3.21 , 2.9  , 2.07 , 2.36 , 2.64 , 3.08 , 3.5  , 3.54 ,
#        2.87 ])

# %%
df["stroke"].value_counts()
# Out:
# 3.400    20
# 3.230    14
# 3.150    14
# 3.030    14
# 3.390    13
# 2.640    11
# 3.290     9
# 3.350     9
# 3.460     8
# 3.110     6
# 3.270     6
# 3.410     6
# 3.070     6
# 3.580     6
# 3.190     6
# 3.500     6
# 3.640     5
# 3.520     5
# 3.860     4
# 3.540     4
# 3.470     4
# 3.255     4
# 3.900     3
# 2.900     3
# 3.100     2
# 4.170     2
# 2.800     2
# 2.190     2
# 3.080     2
# 2.680     2
# 2.360     1
# 3.160     1
# 2.070     1
# 3.210     1
# 3.120     1
# 2.760     1
# 2.870     1
# Name: stroke, dtype: int64

# %%
 sns.histplot(x="stroke" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
df["horsepower"].unique()
# Out:
# array([111, 154, 102, 115, 110, 140, 160, 101, 121, 182,  48,  70,  68,
#         88, 145,  58,  76,  60,  86, 100,  78,  90, 176, 262, 135,  84,
#         64, 120,  72, 123, 155, 184, 175, 116,  69,  55,  97, 152, 200,
#         95, 142, 143, 207, 288,  73,  82,  94,  62,  56, 112,  92, 161,
#        156,  52,  85, 114, 162, 134, 106], dtype=int64)

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 84      5
# 90      5
# 82      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 73      3
# 182     3
# 121     3
# 85      3
# 152     3
# 176     2
# 94      2
# 56      2
# 112     2
# 161     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 140     1
# 115     1
# 134     1
# 78      1
# 142     1
# 288     1
# 143     1
# 48      1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: horsepower, dtype: int64

# %%
 sns.histplot(x="horsepower" , y = "price" , data = df)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x= "carbody" , y = "price" , data = df , hue = "fueltype"  )
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x= "carlength" , y = "price" , data = df , hue = "fueltype"  )
# Out:
# <AxesSubplot:xlabel='carlength', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x= "carwidth" , y = "price" , data = df , hue = "fueltype"  )
# Out:
# <AxesSubplot:xlabel='carwidth', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x= "carheight" , y = "price" , data = df , hue = "fueltype"  )
# Out:
# <AxesSubplot:xlabel='carheight', ylabel='price'>

# %% [markdown]
# ## 12. Split the data

# %%
x = df.drop( "price"     , axis = 1)

# %%
y = df["price"]

# %%
x
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
x.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# dtype: object

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# ## 13.  Let's Standardize iris data

# %%
x
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# ## 14. encoding the Categorical data

# %%
x.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# dtype: object

# %%
x["fueltype"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
x.replace( { "gas" : 1 ,"diesel" : 2  } , inplace=True )

# %%
sns.barplot(x["fueltype"])
# Out:
# <AxesSubplot:xlabel='fueltype'>

# %%
x["aspiration"].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
x.replace( { "std" : 1 ,"turbo" : 2  } , inplace=True )

# %%
sns.barplot(x["aspiration"])
# Out:
# <AxesSubplot:xlabel='aspiration'>

# %%
x["doornumber"].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
x.replace( { "two" : 2 ,"four" : 4  } , inplace=True )

# %%
sns.barplot(x["doornumber"])
# Out:
# <AxesSubplot:xlabel='doornumber'>

# %%
x["carbody"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
x.replace( { "convertible" : 1 ,"hatchback" : 2 , "sedan" : 3 , "wagon" : 4  , "hardtop" : 5 } , inplace=True )

# %%
sns.barplot(x["carbody"])
# Out:
# <AxesSubplot:xlabel='carbody'>

# %%
x["drivewheel"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
x.replace( { "rwd" : 1 ,"fwd" : 2 , "4wd" : 3 } , inplace=True )

# %%
sns.barplot(x["drivewheel"])
# Out:
# <AxesSubplot:xlabel='drivewheel'>

# %%
x["enginelocation"].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
x.replace( { "front" : 1 ,"rear" : 2  } , inplace=True )

# %%
sns.barplot(x["enginelocation"])
# Out:
# <AxesSubplot:xlabel='enginelocation'>

# %%
x["enginetype"].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
x.replace( { "dohc" : 1 ,"ohcv" : 2 , "ohc" : 3 , "l" : 4  , "rotor" : 5 , "ohcf" : 6 , "dohcv" : 7 } , inplace=True )

# %%
sns.barplot(x["enginetype"])
# Out:
# <AxesSubplot:xlabel='enginetype'>

# %%
x["cylindernumber"].unique()
# Out:
# array([4, 'six', 'five', 'three', 'twelve', 2, 'eight'], dtype=object)

# %%
x.replace( { "six" : 6 ,"five" : 5 , "three" : 3 , "twelve" : 12  , "eight" : 8 } , inplace=True )

# %%
sns.barplot(x["cylindernumber"])
# Out:
# <AxesSubplot:xlabel='cylindernumber'>

# %%
x["fuelsystem"].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
x.replace( { "mpfi" : 1 ,"2bbl" : 2 , "mfi" : 3 , "1bbl" : 4  , "spfi" : 5 , "4bbl" : 6 , "idi" : 7 , "spdi" : 8 } , inplace=True )

# %%
sns.barplot(x["fuelsystem"])
# Out:
# <AxesSubplot:xlabel='fuelsystem'>

# %%
x["aspiration"].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
x["aspiration"].value_counts()
# Out:
# 1    168
# 2     37
# Name: aspiration, dtype: int64

# %%
sns.barplot(x["aspiration"])
# Out:
# <AxesSubplot:xlabel='aspiration'>

# %%
x.replace( { "turbo" : 2} , inplace=True )

# %%
x["CarName"].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
x["CarName"].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
Car_name = df.groupby("CarName")["price"].mean().to_dict()

# %%
Car_name
# Out:
# {'Nissan versa': 5499.0,
#  'alfa-romero Quadrifoglio': 16500.0,
#  'alfa-romero giulia': 13495.0,
#  'alfa-romero stelvio': 16500.0,
#  'audi 100 ls': 13950.0,
#  'audi 100ls': 17580.0,
#  'audi 4000': 23875.0,
#  'audi 5000': 18920.0,
#  'audi 5000s (diesel)': 17859.167,
#  'audi fox': 15250.0,
#  'bmw 320i': 16677.5,
#  'bmw x1': 20970.0,
#  'bmw x3': 28992.5,
#  'bmw x4': 30760.0,
#  'bmw x5': 41315.0,
#  'bmw z4': 24565.0,
#  'buick century': 28176.0,
#  'buick century luxus (sw)': 28248.0,
#  'buick century special': 40960.0,
#  'buick electra 225 custom': 25552.0,
#  'buick opel isuzu deluxe': 34184.0,
#  'buick regal sport coupe (turbo)': 45400.0,
#  'buick skyhawk': 31600.0,
#  'buick skylark': 35056.0,
#  'chevrolet impala': 5151.0,
#  'chevrolet monte carlo': 6295.0,
#  'chevrolet vega 2300': 6575.0,
#  'dodge challenger se': 6377.0,
#  'dodge colt (sw)': 7609.0,
#  'dodge colt hardtop': 6692.0,
#  'dodge coronet custom': 8558.0,
#  'dodge coronet custom (sw)': 12964.0,
# ...

# %%
x.replace( Car_name , inplace=True )

# %%
x
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3  13495.0         1           1           2        1
# 1         2          3  16500.0         1           1           2        1
# 2         3          1  16500.0         1           1           2        2
# 3         4          2  13950.0         1           1           4        3
# 4         5          2  17580.0         1           1           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1  14892.5         1           1           4        3
# 201     202         -1  16230.0         1           2           4        3
# 202     203         -1  18735.0         1           1           4        3
# 203     204         -1  22470.0         2           2           4        3
# 204     205         -1  20522.5         1           2           4        3
#
# ...

# %%
x.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName             float64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype            int64
# cylindernumber        int64
# enginesize            int64
# fuelsystem            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# dtype: object

# %% [markdown]
# ## 15. Train-Test-split

# %%
from sklearn.model_selection import  train_test_split

x_train , x_test , y_train , y_test =  train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#      car_ID  symboling       CarName  fueltype  aspiration  doornumber  \
# 204     205         -1  20522.500000         1           2           4
# 163     164          1  12308.000000         1           1           2
# 134     135          3  13605.000000         1           1           2
# 167     168          2   8449.000000         1           1           2
# 80       81          3  11242.333333         1           2           2
# ..      ...        ...           ...       ...         ...         ...
# 50       51          1   5195.000000         1           1           2
# 85       86          1   6989.000000         1           1           4
# 88       89         -1  11242.333333         1           1           4
# 65       66          0  15062.500000         1           1           4
# 9        10          0  17859.167000         1           2           2
#
#      carbody  drivewheel  enginelocation  wheelbase  ...  cylindernumber  \
# ...

# %%
 x_test
# Out:
#      car_ID  symboling       CarName  fueltype  aspiration  doornumber  \
# 28       29         -1   8921.000000         1           1           4
# 146     147          0   7463.000000         1           1           4
# 58       59          3  15645.000000         1           1           2
# 114     115          0  17075.000000         2           2           4
# 10       11          2  16677.500000         1           1           2
# 166     167          1   9538.000000         1           1           2
# 22       23          1   6377.000000         1           1           2
# 178     179          3  12308.000000         1           1           2
# 73       74          0  40960.000000         1           1           4
# 200     201         -1  14892.500000         1           1           4
# 43       44          0   6785.000000         1           1           4
# 18       19          2   5151.000000         1           1           2
# ...

# %%
y_train
# Out:
# 204    22625.000
# 163     8058.000
# 134    15040.000
# 167     8449.000
# 80      9959.000
#          ...
# 50      5195.000
# 85      6989.000
# 88      9279.000
# 65     18280.000
# 9      17859.167
# Name: price, Length: 164, dtype: float64

# %%
 y_test
# Out:
# 28      8921.0
# 146     7463.0
# 58     15645.0
# 114    17075.0
# 10     16430.0
# 166     9538.0
# 22      6377.0
# 178    16558.0
# 73     40960.0
# 200    16845.0
# 43      6785.0
# 18      5151.0
# 186     8495.0
# 20      6575.0
# 156     6938.0
# 195    13415.0
# 128    37028.0
# 81      8499.0
# 8      23875.0
# 124    12764.0
# 104    17199.0
# 45      8916.5
# 177    11248.0
# 102    14399.0
# 106    18399.0
# 59      8845.0
# 61     10595.0
# 56     11845.0
# 165     9298.0
# 144     9233.0
# 180    15690.0
# 107    11900.0
# 95      7799.0
# 108    13200.0
# 171    11549.0
# 97      7999.0
# 137    18620.0
# 127    34028.0
# 3      13950.0
# 110    13860.0
# 151     6338.0
# Name: price, dtype: float64

# %% [markdown]
# ## 16 Apply Models

# %% [markdown]
# ### **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_Pred = model.predict(x_test)

# %% [markdown]
# ### **check model**

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_Pred)

# %%
r2
# Out:
# 0.9545419693248489

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
MAE = mean_absolute_error(y_test,y_Pred)
MAE
# Out:
# 1289.3063096894616

# %%
np.sqrt(MAE) # root mean squared error
# Out:
# 35.90691172587057

# %%
MSE = mean_squared_error(y_test,y_Pred)
MSE
# Out:
# 2824452.350283293

# %%
model.score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2828\3947582719.py in <module>
# ----> 1 model.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'

# %% [markdown]
# ## 17. result summary

# %%
import statsmodels.api as sm
x_train_Sm =sm.add_constant(x_train)
x_train_Sm =sm.add_constant(x_train)

ls=sm.OLS(y_train,x_train).fit()
print(ls.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                              764.7
# Date:                Thu, 06 Apr 2023   Prob (F-statistic):                   3.97e-136
# Time:                        16:02:33   Log-Likelihood:                         -1409.8
# No. Observations:                 164   AIC:                                      2870.
# Df Residuals:                     139   BIC:                                      2947.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
